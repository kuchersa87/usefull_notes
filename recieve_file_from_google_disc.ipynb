# %%
# Оригинальная ссылка на файл, доступ к файлу должен быть открыт
https://docs.google.com/spreadsheets/d/1dxpYtyCxmDIgI8jbFXcz-sdlzP4R6Zy-/edit?usp=share_link&ouid=112578139344017122682&rtpof=true&sd=true
# Ссылку необходимо откорректировать!
# 1 - удалить остаток после адреса :1dxpYtyCxmDIgI8jbFXcz-sdlzP4R6Zy-/
# Итого после удаления: https://docs.google.com/spreadsheets/d/1dxpYtyCxmDIgI8jbFXcz-sdlzP4R6Zy-/
# 2 - добавить export?format=
# 3 - Указать формат файла

# %%
from io import BytesIO
import requests
import pandas as pd
# Проверить корректность ссылки и ФОРМАТА файла
link = 'https://docs.google.com/spreadsheets/d/1dxpYtyCxmDIgI8jbFXcz-sdlzP4R6Zy-/export?format=xlsx'
req = requests.get(link)
data = req.content
# Проверить функцию для открытия файла
df = pd.read_excel(BytesIO(data))

# %%
df.head(3)
# Out:
#                               Имя              TQS_Инициатор  \
# 0  UMCD-UM1-PO1-TQS-02255-CIV.xml  Дирекция по строительству
# 1   RHI-UM1-PO1-TQS-01676-EQP.xml                  Подрядчик
# 2   RHI-UM1-PO1-TQS-01675-ELE.xml                  Подрядчик
#
#               TQS_ФИО Инициатор  \
# 0  Кистерев Геннадий Николаевич
# 1    Эрдынеева Наталья Баировна
# 2    Эрдынеева Наталья Баировна
#
#                                      TQS_Организация  \
# 0  Дирекция по строительству - ПО-1 - ООО "Удокан...
# 1                          Ренейссанс Хэви Индастрис
# 2                          Ренейссанс Хэви Индастрис
#
#                                     TQS_Тема запроса  \
# 0                Отсутствия информации по фундаменту
# 1  О требовании избыточного довления и ваккумиров...
# 2  Кабельные лотки, идущие от линии 3.12 и входящ...
#
#      TQS_Номер комплекта РД    TQS_Номер по генплану TQS_Чего касается TQS  \
# 0      У1.ТК.07.05-3705-КЖ3  Отсутствует номер по ГП             Общестрой
# 1   У1.ТК.04.01-3705-5.1-ТХ                     5.01          Оборудование
# 2  У1.ТК.01.09-3705-3.11-ЭМ                     3.11             Электрика
#
#   TQS_РПИ TQS_РПИ_наименование  ... Прогноз ответа АН РПИ  \
# 0     МЕХ  Механобр инжиниринг  ...                   NaN
# 1     МЕХ  Механобр инжиниринг  ...                   NaN
# 2     МЕХ  Механобр инжиниринг  ...                   NaN
#
#   Прогноз ответа РПИ (тех. решение) Прогноз ответа ДП_ДС УМ  \
# 0                               NaN                     NaN
# 1                               NaN                     NaN
# 2                               NaN                     NaN
#
#   Прогноз ответа РПИ (корректировка РД) ID_number_initiator Тип элемента  \
# 0                                   NaN                2255      Элемент
# 1                                   NaN                1676      Элемент
# 2                                   NaN                1675      Элемент
#
#         Путь TQS_Дата создания TQS_Факт закрытия TQS TQS_Номер TQS
# 0  p/um1/TQS               NaN                   NaN           NaN
# 1  p/um1/TQS               NaN                   NaN           NaN
# 2  p/um1/TQS               NaN                   NaN           NaN
#
# [3 rows x 90 columns]
